# %%
import pytesseract
import cv2
import os
import numpy as np
import re
from time import time
from skimage import color as skicolor

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def get_year(img):
    start = time()
    
    im = cv2.imread(img)
    
    gray =  cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    print(gray.shape)
#     gray = cv2.imread(img, 0)
#     print(gray)
    
    h, w = gray.shape
    if h/w > 1: 
        gray = cv2.rotate(gray, cv2.cv2.ROTATE_90_CLOCKWISE)
        im = cv2.rotate(im, cv2.cv2.ROTATE_90_CLOCKWISE)
    
    gray = cv2.resize( gray, None, fx = 3, fy = 3, interpolation = cv2.INTER_CUBIC)
    im = cv2.resize(im, None, fx = 3, fy = 3, interpolation = cv2.INTER_CUBIC)
    blur = cv2.GaussianBlur(gray, (5,5), 0)
    gray = cv2.medianBlur(gray, 3)
    ret, thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_OTSU | cv2.THRESH_BINARY)


    rect_kern = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
    dilation = cv2.dilate(thresh, rect_kern, iterations = 1)

    # find contours
    try:
        contours, hierarchy = cv2.findContours(dilation, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    except:
        ret_img, contours, hierarchy = cv2.findContours(dilation, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    sorted_contours = sorted(contours, key=lambda ctr: cv2.boundingRect(ctr)[0])

    # create copy of image
    im2 = dilation.copy()
    height, width = im2.shape

    plate_num = ""

    color = (0,215,255)
    # loop through contours and find letters in license plate
    for cnt in sorted_contours:
        x,y,w,h = cv2.boundingRect(cnt)

        if height / float(h) > 3: continue
        ratio = h / float(w)
        if ratio < 1.25: continue
        area = h * w
        if width / float(w) > 20: continue
        if area < 100: continue
            
        # draw the rectangle
        rect = cv2.rectangle(im, (x,y), (x+w, y+h), color,2)
        padding = 0
        roi = thresh[y-padding:y+h+padding, x-padding:x+w+padding]
        roi = cv2.bitwise_not(roi)
        roi = cv2.medianBlur(roi, 5)

        text = pytesseract.image_to_string(roi, config='-c tessedit_char_whitelist=0123456789 --psm 8 --oem 3')
        clean_text = re.sub('[\W_]+', '', text)
        plate_num += clean_text
        
        
        
    print(img, plate_num)
    if plate_num != None:
        cv2.putText(im, plate_num, (int(width/2), int(height/2)), cv2.FONT_HERSHEY_SIMPLEX, 2, color, 3)
#     cv2.imshow("Character's Segmented", im2)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    end = time() - start
    return im, end

# %%
path = "./data/images"

time_lst = []

for file in os.listdir(path):
    if file == ".ipynb_checkpoints": continue
    if os.path.isfile(f"{path}/{file}"):
        img, t = get_year(f"{path}/{file}")
        cv2.imwrite(f"{path}/recognized/{file}", img)
        time_lst.append(t)
# Out:
# (115, 196)
# ./data/images/00032_2.jpg
# (246, 436)
# ./data/images/00040_1.jpg
# (81, 188)
# ./data/images/00050_2.jpg
# (70, 148)
# ./data/images/00052_2.jpg
# (70, 148)
# ./data/images/00054_2.jpg
# (53, 79)
# ./data/images/00060_1.jpg 7
# (161, 223)
# ./data/images/00062_2.jpg
# (74, 171)
# ./data/images/00070_1.jpg
# (142, 270)
# ./data/images/00094_1.jpg 4
# (142, 270)
# ./data/images/00096_1.jpg
# (40, 85)
# ./data/images/00100_1.jpg 4
# (40, 89)
# ./data/images/00102_2.jpg 3
# (183, 75)
# ./data/images/00144_2.jpg
# (49, 126)
# ./data/images/00146_1.jpg
# (49, 126)
# ./data/images/00148_1.jpg
# (23, 33)
# ./data/images/00156_1.jpg
# (48, 58)
# ./data/images/00174_1.jpg
# (98, 206)
# ./data/images/00212_2.jpg
# (10, 26)
# ./data/images/00272_2.jpg 1
# (165, 62)
# ./data/images/00284_1.jpg
# (165, 62)
# ./data/images/00286_1.jpg
# (74, 152)
# ./data/images/00320_1.jpg
# (53, 144)
# ./data/images/00346_2.jpg 1
# (76, 194)
# ./data/images/00378_2.jpg 33
# (27, 59)
# ./data/images/00388_2.jpg 49
# (180, 383)
# ./data/images/00390_1.jpg
# (180, 383)
# ./data/images/00392_1.jpg 527
# (67, 156)
# ./data/images/00404_2.jpg
# (29, 68)
# ./data/images/00408_2.jpg
# (12, 25)
# ./data/images/00410_2.jpg
# (74, 90)
# ./data/images/00434_1.jpg
# (71, 138)
# ./data/images/00498_2.jpg
# (48, 41)
# ./data/images/00506_1.jpg
# (49, 40)
# ./data/images/00508_1.jpg
# (36, 15)
# ./data/images/00510_2.jpg 7
# (13, 26)
# ./data/images/00516_1.jpg 1
# (91, 173)
# ./data/images/00520_2.jpg
# (36, 54)
# ./data/images/00534_2.jpg
# (36, 54)
# ./data/images/00536_2.jpg
# (31, 62)
# ./data/images/00546_2.jpg 4
# (41, 101)
# ./data/images/00554_2.jpg 8
# (41, 101)
# ./data/images/00556_2.jpg
# (68, 118)
# ./data/images/00562_2.jpg
# (100, 122)
# ./data/images/00578_2.jpg
# (100, 122)
# ./data/images/00580_2.jpg
# (21, 47)
# ./data/images/00584_2.jpg
# (21, 47)
# ./data/images/00586_2.jpg 344
# (17, 32)
# ./data/images/00588_1.jpg
# (51, 139)
# ./data/images/00606_2.jpg
# (74, 137)
# ./data/images/00640_2.jpg 1
# (100, 121)
# ./data/images/00680_2.jpg
# (67, 160)
# ./data/images/00702_2.jpg
# (67, 160)
# ./data/images/00704_2.jpg 1
# (166, 317)
# ./data/images/00718_2.jpg 438
# (81, 140)
# ./data/images/00724_1.jpg
# (75, 27)
# ./data/images/00728_2.jpg 4
# (87, 32)
# ./data/images/00744_1.jpg
# (87, 34)
# ./data/images/00744_2.jpg
# (30, 57)
# ./data/images/00754_2.jpg
# (44, 90)
# ./data/images/00770_2.jpg
# (44, 90)
# ./data/images/00772_2.jpg
# (15, 37)
# ./data/images/00794_1.jpg
# (213, 445)
# ./data/images/00820_2.jpg
# (58, 118)
# ./data/images/00846_2.jpg
# (174, 55)
# ./data/images/00850_3.jpg 2
# (178, 57)
# ./data/images/00850_4.jpg
# (174, 55)
# ./data/images/00852_3.jpg 9
# (178, 57)
# ./data/images/00852_4.jpg 4
# (70, 142)
# ./data/images/00876_2.jpg
# (84, 176)
# ./data/images/00898_2.jpg
# (33, 61)
# ./data/images/00914_2.jpg
# (33, 61)
# ./data/images/00916_2.jpg
# (41, 47)
# ./data/images/00954_1.jpg
# (69, 180)
# ./data/images/00964_2.jpg 4
# (17, 41)
# ./data/images/00968_2.jpg 9
# (38, 50)
# ./data/images/00994_1.jpg
# (49, 135)
# ./data/images/01014_2.jpg
# (37, 69)
# ./data/images/01016_2.jpg
# (22, 52)
# ./data/images/01020_2.jpg 4
# (26, 54)
# ./data/images/01022_2.jpg
# (21, 44)
# ./data/images/01040_2.jpg
# (48, 97)
# ./data/images/01042_2.jpg
# (48, 97)
# ./data/images/01044_2.jpg
# (35, 86)
# ./data/images/01050_2.jpg
# (41, 116)
# ./data/images/01064_2.jpg
# (90, 134)
# ./data/images/01094_2.jpg
# (90, 134)
# ./data/images/01096_2.jpg
# (32, 14)
# ./data/images/01098_1.jpg
# (34, 14)
# ./data/images/01098_10.jpg
# (33, 16)
# ./data/images/01098_11.jpg
# (33, 16)
# ./data/images/01098_17.jpg
# (33, 13)
# ./data/images/01098_18.jpg
# (34, 15)
# ./data/images/01098_2.jpg
# (34, 13)
# ./data/images/01098_3.jpg
# (34, 17)
# ./data/images/01098_8.jpg
# (34, 12)
# ./data/images/01098_9.jpg
# (22, 51)
# ./data/images/01106_2.jpg
# (22, 51)
# ./data/images/01108_2.jpg
# (29, 33)
# ./data/images/01116_2.jpg
# (29, 33)
# ./data/images/01118_2.jpg 4
# (58, 147)
# ./data/images/01120_2.jpg
# (83, 107)
# ./data/images/01122_1.jpg
# (91, 244)
# ./data/images/01162_2.jpg 16
# (128, 57)
# ./data/images/01188_1.jpg
# (100, 185)
# ./data/images/01244_1.jpg 4
# (107, 130)
# ./data/images/01254_2.jpg
# (60, 84)
# ./data/images/01270_1.jpg
# (65, 85)
# ./data/images/01270_11.jpg
# (64, 76)
# ./data/images/01270_3.jpg
# (68, 88)
# ./data/images/01270_5.jpg
# (53, 77)
# ./data/images/01270_7.jpg
# (54, 76)
# ./data/images/01270_9.jpg
# (60, 84)
# ./data/images/01272_1.jpg
# (65, 85)
# ./data/images/01272_11.jpg
# (64, 76)
# ./data/images/01272_3.jpg
# (68, 88)
# ./data/images/01272_5.jpg
# (53, 77)
# ./data/images/01272_7.jpg
# (54, 76)
# ./data/images/01272_9.jpg
# (7, 14)
# ./data/images/01274_2.jpg
# (87, 269)
# ./data/images/01312_2.jpg 2
# (127, 252)
# ./data/images/01312_3.jpg
# (87, 269)
# ./data/images/01314_2.jpg
# (127, 252)
# ./data/images/01314_3.jpg
# (56, 146)
# ./data/images/01324_2.jpg
# (56, 146)
# ./data/images/01326_2.jpg
# (122, 240)
# ./data/images/01330_2.jpg 7
# (122, 240)
# ./data/images/01332_2.jpg 4
# (18, 19)
# ./data/images/01334_2.jpg
# (29, 62)
# ./data/images/01340_2.jpg
# (15, 38)
# ./data/images/01344_2.jpg 1
# (43, 113)
# ./data/images/01358_1.jpg 4
# (117, 66)
# ./data/images/01372_1.jpg 1
# (117, 66)
# ./data/images/01374_1.jpg 4
# (87, 204)
# ./data/images/01404_1.jpg 71
# (87, 204)
# ./data/images/01406_1.jpg
# (34, 66)
# ./data/images/01412_2.jpg 51
# (19, 42)
# ./data/images/01422_2.jpg
# (19, 42)
# ./data/images/01424_2.jpg
# (35, 112)
# ./data/images/01432_2.jpg 4335
# (35, 112)
# ./data/images/01434_2.jpg 6
# (50, 99)
# ./data/images/01436_2.jpg 5
# (86, 175)
# ./data/images/01438_2.jpg 53
# (48, 112)
# ./data/images/01444_2.jpg 4
# (69, 110)
# ./data/images/01446_1.jpg 95
# (69, 110)
# ./data/images/01448_1.jpg 9
# (111, 201)
# ./data/images/01454_2.jpg
# (111, 136)
# ./data/images/01458_2.jpg 4
# (111, 136)
# ./data/images/01460_2.jpg 7
# (61, 154)
# ./data/images/01516_2.jpg
# (67, 100)
# ./data/images/01524_1.jpg
# (36, 90)
# ./data/images/01530_2.jpg 3
# (36, 90)
# ./data/images/01532_2.jpg 3
# (119, 324)
# ./data/images/01548_1.jpg
# (119, 324)
# ./data/images/01550_1.jpg 4
# (92, 237)
# ./data/images/01552_2.jpg
# (92, 237)
# ./data/images/01554_2.jpg
# (36, 82)
# ./data/images/01574_3.jpg 8
# (36, 82)
# ./data/images/01576_3.jpg 44
# (61, 101)
# ./data/images/01590_1.jpg
# (170, 308)
# ./data/images/01592_2.jpg
# (170, 308)
# ./data/images/01594_2.jpg
# (139, 328)
# ./data/images/01596_2.jpg
# (34, 74)
# ./data/images/01600_2.jpg
# (90, 185)
# ./data/images/01606_1.jpg
# (90, 185)
# ./data/images/01608_1.jpg
# (30, 80)
# ./data/images/01640_2.jpg
# (30, 80)
# ./data/images/01642_2.jpg
# (123, 187)
# ./data/images/01658_1.jpg 5
# (123, 187)
# ./data/images/01660_1.jpg 19
# (220, 206)
# ./data/images/01670_1.jpg
# (44, 51)
# ./data/images/01674_2.jpg
# (37, 76)
# ./data/images/01680_1.jpg
# (45, 110)
# ./data/images/01698_1.jpg 1
# (91, 214)
# ./data/images/01724_2.jpg 3
# (51, 172)
# ./data/images/01734_2.jpg
# (47, 117)
# ./data/images/01738_1.jpg
# (81, 181)
# ./data/images/01740_2.jpg
# (61, 136)
# ./data/images/01742_2.jpg
# (78, 30)
# ./data/images/01750_4.jpg
# (75, 30)
# ./data/images/01750_5.jpg
# (78, 28)
# ./data/images/01750_6.jpg
# (18, 37)
# ./data/images/01760_2.jpg
# (16, 47)
# ./data/images/01768_1.jpg
# (20, 44)
# ./data/images/01772_1.jpg
# (20, 44)
# ./data/images/01774_1.jpg
# (32, 61)
# ./data/images/01812_2.jpg 22
# (13, 27)
# ./data/images/01834_2.jpg 144
# (58, 120)
# ./data/images/01856_2.jpg 4
# (58, 120)
# ./data/images/01858_2.jpg 5
# (58, 142)
# ./data/images/01872_2.jpg 454
# (58, 142)
# ./data/images/01874_2.jpg
# (14, 27)
# ./data/images/01880_2.jpg
# (205, 202)
# ./data/images/01918_1.jpg
# (42, 100)
# ./data/images/01924_2.jpg
# (42, 100)
# ./data/images/01926_2.jpg
# (145, 279)
# ./data/images/01948_2.jpg
# (95, 126)
# ./data/images/02002_2.jpg
# (95, 126)
# ./data/images/02004_2.jpg
# (40, 70)
# ./data/images/02006_1.jpg
# (44, 77)
# ./data/images/02012_2.jpg 84
# (43, 57)
# ./data/images/02018_1.jpg
# (43, 57)
# ./data/images/02020_1.jpg
# (68, 168)
# ./data/images/02022_2.jpg 4
# (68, 168)
# ./data/images/02024_2.jpg
# (61, 32)
# ./data/images/02030_2.jpg
# (61, 32)
# ./data/images/02032_2.jpg
# (95, 210)
# ./data/images/02060_2.jpg
# (66, 136)
# ./data/images/02084_2.jpg 1
# (66, 136)
# ./data/images/02086_2.jpg
# (36, 80)
# ./data/images/02088_2.jpg
# (36, 80)
# ./data/images/02090_2.jpg
# (76, 168)
# ./data/images/02104_2.jpg 4
# (76, 168)
# ./data/images/02106_2.jpg
# (42, 80)
# ./data/images/02134_2.jpg
# (42, 80)
# ./data/images/02136_2.jpg 47
# (163, 563)
# ./data/images/02160_2.jpg
# (45, 16)
# ./data/images/02162_3.jpg
# (45, 12)
# ./data/images/02162_4.jpg
# (19, 33)
# ./data/images/02166_2.jpg
# (19, 33)
# ./data/images/02168_2.jpg
# (77, 132)
# ./data/images/02204_2.jpg
# (77, 132)
# ./data/images/02206_2.jpg
# (32, 48)
# ./data/images/02220_2.jpg
# (172, 270)
# ./data/images/02276_2.jpg
# (141, 211)
# ./data/images/02302_2.jpg
# (37, 68)
# ./data/images/02314_2.jpg
# (37, 68)
# ./data/images/02316_2.jpg
# (28, 62)
# ./data/images/02336_2.jpg
# (171, 68)
# ./data/images/02338_2.jpg 194
# (140, 327)
# ./data/images/02382_2.jpg
# (140, 327)
# ./data/images/02384_2.jpg
# (23, 39)
# ./data/images/02390_2.jpg 9
# (114, 253)
# ./data/images/02414_2.jpg
# (114, 253)
# ./data/images/02416_2.jpg
# (68, 102)
# ./data/images/02422_2.jpg
# (75, 170)
# ./data/images/02430_2.jpg 28
# (113, 326)
# ./data/images/02442_2.jpg
# (30, 64)
# ./data/images/02470_2.jpg 59
# (51, 94)
# ./data/images/02476_2.jpg 69
# (71, 175)
# ./data/images/02524_2.jpg 93
# (71, 175)
# ./data/images/02526_2.jpg
# (46, 74)
# ./data/images/02546_2.jpg
# (27, 63)
# ./data/images/02600_2.jpg
# (111, 108)
# ./data/images/02622_1.jpg
# (118, 191)
# ./data/images/02640_2.jpg
# (118, 191)
# ./data/images/02642_2.jpg
# (57, 118)
# ./data/images/02670_2.jpg
# (77, 115)
# ./data/images/02678_1.jpg
# (54, 98)
# ./data/images/02698_2.jpg
# (51, 90)
# ./data/images/02700_2.jpg 4
# (51, 90)
# ./data/images/02702_2.jpg
# (173, 323)
# ./data/images/02728_2.jpg
# (34, 120)
# ./data/images/02748_2.jpg
# (34, 120)
# ./data/images/02750_2.jpg
# (87, 254)
# ./data/images/02774_2.jpg 5
# (25, 59)
# ./data/images/02784_2.jpg
# (25, 59)
# ./data/images/02786_2.jpg 48
# (28, 74)
# ./data/images/02792_1.jpg 41
# (39, 119)
# ./data/images/02794_2.jpg 8
# (20, 27)
# ./data/images/02806_1.jpg
# (20, 27)
# ./data/images/02808_1.jpg
# (21, 59)
# ./data/images/02826_1.jpg 8
# (124, 293)
# ./data/images/02842_2.jpg
# (67, 192)
# ./data/images/02868_3.jpg
# (67, 192)
# ./data/images/02870_3.jpg
# (36, 51)
# ./data/images/02876_1.jpg
# (36, 51)
# ./data/images/02878_1.jpg
# (44, 106)
# ./data/images/02930_2.jpg
# (171, 261)
# ./data/images/02940_2.jpg
# (171, 261)
# ./data/images/02942_2.jpg
# (56, 137)
# ./data/images/02964_2.jpg
# (56, 137)
# ./data/images/02966_2.jpg
# (83, 179)
# ./data/images/02980_2.jpg 64
# (83, 179)
# ./data/images/02982_2.jpg 3
# (96, 34)
# ./data/images/02998_2.jpg 4
# (96, 34)
# ./data/images/03000_2.jpg
# (77, 153)
# ./data/images/03030_2.jpg
# (77, 153)
# ./data/images/03032_2.jpg
# (23, 44)
# ./data/images/03060_2.jpg
# (26, 65)
# ./data/images/03072_2.jpg 25
# (26, 65)
# ./data/images/03074_2.jpg 1
# (59, 107)
# ./data/images/03086_2.jpg 1
# (36, 78)
# ./data/images/03088_2.jpg
# (36, 78)
# ./data/images/03090_2.jpg 3
# (47, 108)
# ./data/images/03094_2.jpg
# (47, 108)
# ./data/images/03096_2.jpg
# (47, 93)
# ./data/images/03150_2.jpg 98
# (187, 364)
# ./data/images/03154_2.jpg
# (91, 231)
# ./data/images/03174_2.jpg
# (43, 85)
# ./data/images/03178_2.jpg 3
# (41, 119)
# ./data/images/03196_2.jpg
# (41, 119)
# ./data/images/03198_2.jpg 4
# (28, 64)
# ./data/images/03214_2.jpg
# (33, 72)
# ./data/images/03226_2.jpg
# (82, 280)
# ./data/images/03232_2.jpg
# (19, 41)
# ./data/images/03244_2.jpg
# (16, 40)
# ./data/images/03342_1.jpg
# (25, 111)
# ./data/images/03362_2.jpg
# (49, 114)
# ./data/images/03402_2.jpg 6
# (28, 90)
# ./data/images/03416_2.jpg
# (28, 90)
# ./data/images/03418_2.jpg 1
# (37, 103)
# ./data/images/03420_1.jpg 4
# (42, 95)
# ./data/images/03420_3.jpg
# (37, 103)
# ./data/images/03422_1.jpg
# (42, 95)
# ./data/images/03422_3.jpg
# (67, 139)
# ./data/images/03448_2.jpg 17
# (67, 139)
# ./data/images/03450_2.jpg 7
# (62, 113)
# ./data/images/03462_1.jpg
# (74, 204)
# ./data/images/03466_2.jpg 486
# (31, 89)
# ./data/images/03492_2.jpg 4
# (31, 89)
# ./data/images/03494_2.jpg
# (51, 76)
# ./data/images/03500_2.jpg
# (68, 111)
# ./data/images/03508_2.jpg
# (75, 180)
# ./data/images/03514_2.jpg
# (75, 180)
# ./data/images/03516_2.jpg 3
# (45, 95)
# ./data/images/03536_2.jpg
# (80, 130)
# ./data/images/03540_2.jpg
# (91, 157)
# ./data/images/03540_4.jpg
# (80, 130)
# ./data/images/03542_2.jpg
# (91, 157)
# ./data/images/03542_4.jpg
# (60, 90)
# ./data/images/03544_1.jpg
# (122, 216)
# ./data/images/03554_2.jpg
# (83, 196)
# ./data/images/03602_2.jpg 3
# (108, 250)
# ./data/images/03634_2.jpg
# (74, 154)
# ./data/images/03640_2.jpg 3
# (74, 154)
# ./data/images/03642_2.jpg
# (27, 69)
# ./data/images/03662_2.jpg 4
# (27, 69)
# ./data/images/03664_2.jpg
# (51, 85)
# ./data/images/03670_2.jpg 68
# (51, 85)
# ./data/images/03672_2.jpg 86
# (68, 28)
# ./data/images/03704_1.jpg
# (66, 30)
# ./data/images/03704_2.jpg
# (24, 15)
# ./data/images/03708_10.jpg
# (20, 13)
# ./data/images/03708_12.jpg
# (24, 10)
# ./data/images/03708_4.jpg
# (23, 11)
# ./data/images/03708_5.jpg
# (22, 12)
# ./data/images/03708_6.jpg
# (24, 11)
# ./data/images/03708_8.jpg
# (48, 22)
# ./data/images/03752_1.jpg 4
# (48, 22)
# ./data/images/03754_1.jpg 24
# (163, 279)
# ./data/images/03766_2.jpg 33
# (72, 79)
# ./data/images/03790_2.jpg
# (39, 77)
# ./data/images/03792_2.jpg
# (39, 77)
# ./data/images/03794_2.jpg 4
# (23, 51)
# ./data/images/03796_1.jpg
# (46, 79)
# ./data/images/03798_2.jpg 9
# (29, 45)
# ./data/images/03838_2.jpg
# (29, 45)
# ./data/images/03840_2.jpg
# (53, 21)
# ./data/images/03928_2.jpg
# (43, 82)
# ./data/images/03956_2.jpg 8
# (43, 82)
# ./data/images/03958_2.jpg
# (87, 169)
# ./data/images/03982_2.jpg
# (87, 169)
# ./data/images/03984_2.jpg 4
# (84, 172)
# ./data/images/04014_2.jpg
# (29, 65)
# ./data/images/04040_2.jpg
# (29, 65)
# ./data/images/04042_2.jpg
# (160, 280)
# ./data/images/04044_2.jpg 4
# (12, 32)
# ./data/images/04152_2.jpg
# (69, 151)
# ./data/images/04194_2.jpg 7
# (69, 151)
# ./data/images/04196_2.jpg 7
# (126, 142)
# ./data/images/04198_2.jpg
# (85, 173)
# ./data/images/04202_2.jpg 17
# (47, 104)
# ./data/images/04206_2.jpg
# (47, 104)
# ./data/images/04208_2.jpg 4
# (210, 686)
# ./data/images/04228_2.jpg
# (210, 686)
# ./data/images/04230_2.jpg
# (34, 67)
# ./data/images/04266_1.jpg 5
# (43, 18)
# ./data/images/04284_1.jpg
# (45, 20)
# ./data/images/04298_2.jpg 5
# (44, 17)
# ./data/images/04298_3.jpg 23
# (46, 16)
# ./data/images/04298_4.jpg 3
# (43, 17)
# ./data/images/04298_5.jpg 33
# (42, 17)
# ./data/images/04298_6.jpg 2
# (45, 20)
# ./data/images/04300_2.jpg 4
# (44, 17)
# ./data/images/04300_3.jpg
# (46, 16)
# ./data/images/04300_4.jpg 48
# (43, 17)
# ./data/images/04300_5.jpg
# (42, 17)
# ./data/images/04300_6.jpg 3
# (34, 89)
# ./data/images/04310_2.jpg
# (34, 89)
# ./data/images/04312_2.jpg
# (77, 243)
# ./data/images/04316_1.jpg 1
# (77, 243)
# ./data/images/04318_1.jpg
# (22, 37)
# ./data/images/04340_1.jpg
# (21, 48)
# ./data/images/04384_1.jpg
# (92, 198)
# ./data/images/04396_2.jpg
# (51, 93)
# ./data/images/04420_2.jpg 4
# (51, 93)
# ./data/images/04422_2.jpg
# (73, 120)
# ./data/images/04460_2.jpg
